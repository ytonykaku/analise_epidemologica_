# %% [markdown]
# #

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import glob

# 1. Leitura e união dos arquivos CSV com tratamento de linhas problemáticas
file_paths = glob.glob("*.csv")  # Certifique-se de executar no diretório correto

dataframes = []
for file in file_paths:
    try:
        df = pd.read_csv(file, sep=';', encoding='utf-8', on_bad_lines='skip', low_memory=False)
        dataframes.append(df)
        print(f"{file}: carregado com sucesso!")
    except Exception as e:
        print(f"Erro ao carregar {file}: {e}")

data = pd.concat(dataframes, ignore_index=True)

# 2. Pré-processamento básico
# Converter datas para o formato datetime
data['dataNotificacao'] = pd.to_datetime(data['dataNotificacao'], errors='coerce')

# 3. Análise descritiva
## Principais sintomas
sintomas_counts = data['sintomas'].str.get_dummies(sep=',').sum().sort_values(ascending=False)

## Incidências por município
municipios_counts = data['municipioNotificacao'].value_counts()

## Incidências por raça/cor
raca_counts = data['racaCor'].value_counts()

## Doses de vacina
vacina_counts = data['codigoDosesVacina'].value_counts()

## Incidências por mês
data['mes'] = data['dataNotificacao'].dt.to_period('M')
mes_counts = data['mes'].value_counts().sort_index()

# 4. Visualizações
plt.figure(figsize=(10, 6))
sintomas_counts.head(10).plot(kind='bar', color='skyblue')
plt.title('Top 10 Sintomas Registrados')
plt.xlabel('Sintomas')
plt.ylabel('Frequência')
plt.xticks(rotation=45)
plt.show()

plt.figure(figsize=(10, 6))
municipios_counts.head(10).plot(kind='bar', color='salmon')
plt.title('Top 10 Municípios com Mais Incidências')
plt.xlabel('Município')
plt.ylabel('Frequência')
plt.xticks(rotation=45)
plt.show()

plt.figure(figsize=(10, 6))
raca_counts.plot(kind='bar', color='green')
plt.title('Incidências por Raça/Cor')
plt.xlabel('Raça/Cor')
plt.ylabel('Frequência')
plt.xticks(rotation=45)
plt.show()

plt.figure(figsize=(10, 6))
mes_counts.plot(kind='bar', color='purple')
plt.title('Incidências por Mês')
plt.xlabel('Mês')
plt.ylabel('Frequência')
plt.xticks(rotation=45)
plt.show()

plt.figure(figsize=(10, 6))
vacina_counts.plot(kind='bar', color='orange')
plt.title('Doses de Vacina Administradas')
plt.xlabel('Doses')
plt.ylabel('Frequência')
plt.xticks(rotation=45)
plt.show()

# 5. Salvar resultados principais para análise adicional
sintomas_counts.to_csv('sintomas_counts.csv', index=True)
municipios_counts.to_csv('municipios_counts.csv', index=True)
raca_counts.to_csv('raca_counts.csv', index=True)
vacina_counts.to_csv('vacina_counts.csv', index=True)
mes_counts.to_csv('mes_counts.csv', index=True)

print("Análise e salvamento de resultados concluídos com sucesso!")
# Out:
# 2022-1.csv: carregado com sucesso!
# 2022-10.csv: carregado com sucesso!
# 2022-11.csv: carregado com sucesso!
# 2022-12.csv: carregado com sucesso!
# 2022-2.csv: carregado com sucesso!
# 2022-3.csv: carregado com sucesso!
# 2022-4.csv: carregado com sucesso!
# 2022-5.csv: carregado com sucesso!
# 2022-6.csv: carregado com sucesso!
# 2022-7.csv: carregado com sucesso!
# 2022-8.csv: carregado com sucesso!
# 2022-9.csv: carregado com sucesso!
# 2023-1.csv: carregado com sucesso!
# 2024-1.csv: carregado com sucesso!
# Análise e salvamento de resultados concluídos com sucesso!

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import glob

# 1. Leitura e união dos arquivos CSV com tratamento de linhas problemáticas
file_paths = glob.glob("*.csv")  # Certifique-se de executar no diretório correto

dataframes = []
for file in file_paths:
    try:
        df = pd.read_csv(file, sep=';', encoding='utf-8', on_bad_lines='skip', low_memory=False)
        dataframes.append(df)
        print(f"{file}: carregado com sucesso!")
    except Exception as e:
        print(f"Erro ao carregar {file}: {e}")

data = pd.concat(dataframes, ignore_index=True)

# 2. Pré-processamento básico
# Converter datas para o formato datetime
data['dataNotificacao'] = pd.to_datetime(data['dataNotificacao'], errors='coerce')

# 3. Análise descritiva
## Principais sintomas
sintomas_counts = data['sintomas'].str.get_dummies(sep=',').sum().sort_values(ascending=False)

## Incidências por município
municipios_counts = data['municipioNotificacao'].value_counts()

## Incidências por raça/cor
raca_counts = data['racaCor'].value_counts()

## Doses de vacina
vacina_counts = data['codigoDosesVacina'].value_counts()

## Incidências por mês
# Extraindo apenas o nome do mês
data['mes'] = data['dataNotificacao'].dt.month_name()
mes_counts = data['mes'].value_counts().reindex(
    ["January", "February", "March", "April", "May", "June", 
     "July", "August", "September", "October", "November", "December"]
)

# 4. Visualizações
plt.figure(figsize=(10, 6))
sintomas_counts.head(10).plot(kind='bar', color='skyblue')
plt.title('Top 10 Sintomas Registrados')
plt.xlabel('Sintomas')
plt.ylabel('Frequência')
plt.xticks(rotation=45)
plt.gca().get_yaxis().get_offset_text().set_visible(False)  # Remove 10^6 no eixo Y
plt.show()

plt.figure(figsize=(10, 6))
municipios_counts.head(10).plot(kind='bar', color='salmon')
plt.title('Top 10 Municípios com Mais Incidências')
plt.xlabel('Município')
plt.ylabel('Frequência')
plt.xticks(rotation=45)
plt.gca().get_yaxis().get_offset_text().set_visible(False)  # Remove 10^6 no eixo Y
plt.show()

plt.figure(figsize=(10, 6))
raca_counts.plot(kind='bar', color='green')
plt.title('Incidências por Raça/Cor')
plt.xlabel('Raça/Cor')
plt.ylabel('Frequência')
plt.xticks(rotation=45)
plt.gca().get_yaxis().get_offset_text().set_visible(False)  # Remove 10^6 no eixo Y
plt.show()

plt.figure(figsize=(10, 6))
mes_counts.plot(kind='bar', color='purple')
plt.title('Incidências por Mês')
plt.xlabel('Mês')
plt.ylabel('Frequência')
plt.xticks(rotation=45)
plt.gca().get_yaxis().get_offset_text().set_visible(False)  # Remove 10^6 no eixo Y
plt.show()

plt.figure(figsize=(10, 6))
vacina_counts.plot(kind='bar', color='orange')
plt.title('Doses de Vacina Administradas')
plt.xlabel('Doses')
plt.ylabel('Frequência')
plt.xticks(rotation=45)
plt.gca().get_yaxis().get_offset_text().set_visible(False)  # Remove 10^6 no eixo Y
plt.show()

# 5. Salvar resultados principais para análise adicional
sintomas_counts.to_csv('sintomas_counts.csv', index=True)
municipios_counts.to_csv('municipios_counts.csv', index=True)
raca_counts.to_csv('raca_counts.csv', index=True)
vacina_counts.to_csv('vacina_counts.csv', index=True)
mes_counts.to_csv('mes_counts.csv', index=True)

print("Análise e salvamento de resultados concluídos com sucesso!")
# Out:
# /home/tonykaku/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "
# 2022-1.csv: carregado com sucesso!
# 2022-10.csv: carregado com sucesso!
# 2022-11.csv: carregado com sucesso!
# 2022-12.csv: carregado com sucesso!
# 2022-2.csv: carregado com sucesso!
# 2022-3.csv: carregado com sucesso!
# 2022-4.csv: carregado com sucesso!
# 2022-5.csv: carregado com sucesso!
# 2022-6.csv: carregado com sucesso!
# 2022-7.csv: carregado com sucesso!
# 2022-8.csv: carregado com sucesso!
# 2022-9.csv: carregado com sucesso!
# 2023-1.csv: carregado com sucesso!
# 2024-1.csv: carregado com sucesso!
# mes_counts.csv: carregado com sucesso!
# municipios_counts.csv: carregado com sucesso!
# raca_counts.csv: carregado com sucesso!
# sintomas_counts.csv: carregado com sucesso!
# vacina_counts.csv: carregado com sucesso!
# Análise e salvamento de resultados concluídos com sucesso!

# %%
import pandas as pd
import matplotlib.pyplot as plt
import glob

# 1. Leitura e união dos arquivos CSV com tratamento de linhas problemáticas
file_paths = glob.glob("*.csv")  # Certifique-se de executar no diretório correto

dataframes = []
for file in file_paths:
    try:
        df = pd.read_csv(file, sep=';', encoding='utf-8', on_bad_lines='skip', low_memory=False)
        dataframes.append(df)
        print(f"{file}: carregado com sucesso!")
        if file == "2024-1.csv":
            break  # Para a leitura ao encontrar o arquivo "2024-1.csv"
    except Exception as e:
        print(f"Erro ao carregar {file}: {e}")

data = pd.concat(dataframes, ignore_index=True)

# 2. Pré-processamento básico
# Converter datas para o formato datetime
data['dataNotificacao'] = pd.to_datetime(data['dataNotificacao'], errors='coerce')

# Filtrar notificações entre 2022 e 2024
data = data[(data['dataNotificacao'] >= '2022-01-01') & (data['dataNotificacao'] <= '2024-12-31')]

# 3. Análise descritiva
## Principais sintomas
sintomas_counts = data['sintomas'].str.get_dummies(sep=',').sum().sort_values(ascending=False)

## Incidências por município
municipios_counts = data['municipioNotificacao'].value_counts()

## Incidências por raça/cor
raca_counts = data['racaCor'].value_counts()

## Doses de vacina
vacina_counts = data['codigoDosesVacina'].value_counts()

## Incidências por mês
data['mes'] = data['dataNotificacao'].dt.to_period('M')
mes_counts = data['mes'].value_counts().sort_index()

# 4. Visualizações
plt.figure(figsize=(10, 6))
sintomas_counts.head(10).plot(kind='bar', color='skyblue')
plt.title('Top 10 Sintomas Registrados')
plt.xlabel('Sintomas')
plt.ylabel('Número de Ocorrências')
plt.xticks(rotation=45)
plt.show()

plt.figure(figsize=(10, 6))
municipios_counts.head(10).plot(kind='bar', color='salmon')
plt.title('Top 10 Municípios com Mais Incidências')
plt.xlabel('Município')
plt.ylabel('Número de Ocorrências')
plt.xticks(rotation=45)
plt.show()

plt.figure(figsize=(10, 6))
raca_counts.plot(kind='bar', color='green')
plt.title('Incidências por Raça/Cor')
plt.xlabel('Raça/Cor')
plt.ylabel('Número de Ocorrências')
plt.xticks(rotation=45)
plt.show()

plt.figure(figsize=(10, 6))
mes_counts.plot(kind='bar', color='purple')
plt.title('Incidências por Mês')
plt.xlabel('Mês')
plt.ylabel('Número de Ocorrências')
plt.xticks(rotation=45)
plt.show()

plt.figure(figsize=(10, 6))
vacina_counts.plot(kind='bar', color='orange')
plt.title('Doses de Vacina Administradas')
plt.xlabel('Doses')
plt.ylabel('Número de Ocorrências')
plt.xticks(rotation=45)
plt.show()

# 5. Salvar resultados principais para análise adicional
sintomas_counts.to_csv('sintomas_counts.csv', index=True)
municipios_counts.to_csv('municipios_counts.csv', index=True)
raca_counts.to_csv('raca_counts.csv', index=True)
vacina_counts.to_csv('vacina_counts.csv', index=True)
mes_counts.to_csv('mes_counts.csv', index=True)

print("Análise e salvamento de resultados concluídos com sucesso!")
# Out:
# /home/tonykaku/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "
# 2022-1.csv: carregado com sucesso!
# 2022-10.csv: carregado com sucesso!
# 2022-11.csv: carregado com sucesso!
# 2022-12.csv: carregado com sucesso!
# 2022-2.csv: carregado com sucesso!
# 2022-3.csv: carregado com sucesso!
# 2022-4.csv: carregado com sucesso!
# 2022-5.csv: carregado com sucesso!
# 2022-6.csv: carregado com sucesso!
# 2022-7.csv: carregado com sucesso!
# 2022-8.csv: carregado com sucesso!
# 2022-9.csv: carregado com sucesso!
# 2023-1.csv: carregado com sucesso!
# 2024-1.csv: carregado com sucesso!
# Análise e salvamento de resultados concluídos com sucesso!

# %%
import pandas as pd
import matplotlib.pyplot as plt
import glob

import pandas as pd
import matplotlib.pyplot as plt

# 1. Leitura do arquivo reduzido
file_path = "dados_reduzidos.csv"  # Certifique-se de executar no diretório correto

try:
    data = pd.read_csv(file_path, sep=';', encoding='utf-8', on_bad_lines='skip', low_memory=False)
    print(f"{file_path}: carregado com sucesso!")
except Exception as e:
    print(f"Erro ao carregar {file_path}: {e}")
    data = pd.DataFrame()  # Criar um DataFrame vazio em caso de erro

# 2. Pré-processamento básico
# Converter datas para o formato datetime
data['dataNotificacao'] = pd.to_datetime(data['dataNotificacao'], errors='coerce')

# Filtrar notificações entre 2022 e 2024
data = data[(data['dataNotificacao'] >= '2022-01-01') & (data['dataNotificacao'] <= '2024-12-31')]

# 3. Análise descritiva
## Principais sintomas
sintomas_counts = data['sintomas'].str.get_dummies(sep=',').sum().sort_values(ascending=False)

## Incidências por município
municipios_counts = data['municipioNotificacao'].value_counts()

## Incidências por raça/cor
raca_counts = data['racaCor'].value_counts()

## Doses de vacina
vacina_counts = data['codigoDosesVacina'].value_counts()

## Incidências por mês
data['mes'] = data['dataNotificacao'].dt.to_period('M')
mes_counts = data['mes'].value_counts().sort_index()

# 4. Visualizações
plt.figure(figsize=(10, 6))
sintomas_counts.head(10).plot(kind='bar', color='skyblue')
plt.title('Top 10 Sintomas Registrados')
plt.xlabel('Sintomas')
plt.ylabel('Número de Ocorrências')
plt.xticks(rotation=45)
plt.show()

plt.figure(figsize=(10, 6))
municipios_counts.head(10).plot(kind='bar', color='salmon')
plt.title('Top 10 Municípios com Mais Incidências')
plt.xlabel('Município')
plt.ylabel('Número de Ocorrências')
plt.xticks(rotation=45)
plt.show()

plt.figure(figsize=(10, 6))
raca_counts.plot(kind='bar', color='green')
plt.title('Incidências por Raça/Cor')
plt.xlabel('Raça/Cor')
plt.ylabel('Número de Ocorrências')
plt.xticks(rotation=45)
plt.show()

plt.figure(figsize=(10, 6))
mes_counts.plot(kind='bar', color='purple')
plt.title('Incidências por Mês')
plt.xlabel('Mês')
plt.ylabel('Número de Ocorrências')
plt.xticks(rotation=45)
plt.show()

plt.figure(figsize=(10, 6))
vacina_counts.plot(kind='bar', color='orange')
plt.title('Doses de Vacina Administradas')
plt.xlabel('Doses')
plt.ylabel('Número de Ocorrências')
plt.xticks(rotation=45)
plt.show()

# 5. Salvar resultados principais para análise adicional
sintomas_counts.to_csv('sintomas_counts.csv', index=True)
municipios_counts.to_csv('municipios_counts.csv', index=True)
raca_counts.to_csv('raca_counts.csv', index=True)
vacina_counts.to_csv('vacina_counts.csv', index=True)
mes_counts.to_csv('mes_counts.csv', index=True)

print("Análise e salvamento de resultados concluídos com sucesso!")
# Out:
# /home/tonykaku/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "
# dados_reduzidos.csv: carregado com sucesso!
# Análise e salvamento de resultados concluídos com sucesso!

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline
import numpy as np

# 1. Leitura do arquivo reduzido
file_path = "dados_reduzidos.csv"  # Certifique-se de executar no diretório correto

try:
    data = pd.read_csv(file_path, sep=';', encoding='utf-8', on_bad_lines='skip', low_memory=False)
    print(f"{file_path}: carregado com sucesso!")
except Exception as e:
    print(f"Erro ao carregar {file_path}: {e}")
    data = pd.DataFrame()  # Criar um DataFrame vazio em caso de erro

# 2. Processamento dos dados
data['dataNotificacao'] = pd.to_datetime(data['dataNotificacao'], errors='coerce')
data = data.dropna(subset=['dataNotificacao'])
data = data[data['dataNotificacao'].dt.year > 2021]
data['ano_mes'] = data['dataNotificacao'].dt.to_period('M').astype(str)

# 3. Predição geral para MG
notificacoes_geral = data.groupby('ano_mes').size().reset_index(name='quantidade')

plt.figure(figsize=(12, 6))
plt.plot(notificacoes_geral['ano_mes'], notificacoes_geral['quantidade'], marker='o', linestyle='-')
plt.xticks(rotation=45)
plt.xlabel("Ano-Mês")
plt.ylabel("Número de Notificações")
plt.title("Evolução do Número de Notificações por Mês - MG")
plt.grid()
plt.show()

# 4. Predição para as 10 cidades com mais notificações
top10_cidades = data['municipioNotificacao'].value_counts().nlargest(10).index
data_top10 = data[data['municipioNotificacao'].isin(top10_cidades)].copy()  # Criar cópia para evitar warnings
notificacoes_top10 = data_top10.groupby(['municipioNotificacao', 'ano_mes']).size().reset_index(name='quantidade')

fig, ax = plt.subplots(figsize=(12, 6))
for municipio in top10_cidades:
    df_mun = notificacoes_top10[notificacoes_top10['municipioNotificacao'] == municipio]
    plt.plot(df_mun['ano_mes'], df_mun['quantidade'], marker='o', linestyle='-', label=municipio)

plt.xticks(rotation=45)
plt.xlabel("Ano-Mês")
plt.ylabel("Número de Notificações")
plt.title("Evolução do Número de Notificações por Mês - Top 10 Municípios")
plt.legend()
plt.grid()
plt.show()

# 5. Predição do próximo mês (Geral e Top 10 municípios)
def prever_proximo_mes(notificacoes):
    notificacoes = notificacoes.copy()  # Evita warnings de slice de DataFrame
    notificacoes['ano_mes'] = pd.to_datetime(notificacoes['ano_mes'].astype(str))
    notificacoes['timestamp'] = (notificacoes['ano_mes'] - notificacoes['ano_mes'].min()).dt.days
    
    X = notificacoes[['timestamp']]
    y = notificacoes['quantidade']
    
    modelo = make_pipeline(PolynomialFeatures(2), LinearRegression())
    modelo.fit(X, y)
    
    proximo_mes = pd.DataFrame({'timestamp': [notificacoes['timestamp'].max() + 30]})  # Mantendo a estrutura
    previsao = modelo.predict(proximo_mes)  # Previsão com formato correto
    previsao = max(0, previsao[0])
    
    return previsao

previsao_geral = prever_proximo_mes(notificacoes_geral)
print(f"Previsão para o próximo mês em MG: {previsao_geral}")

for municipio in top10_cidades:
    df_mun = notificacoes_top10[notificacoes_top10['municipioNotificacao'] == municipio].copy()
    previsao_municipio = prever_proximo_mes(df_mun)
    print(f"Previsão para o próximo mês em {municipio}: {previsao_municipio}")
# Out:
# dados_reduzidos.csv: carregado com sucesso!
# Previsão para o próximo mês em MG: 29693.733478746668
# Previsão para o próximo mês em Belo Horizonte: 6182.295703733249
# Previsão para o próximo mês em Contagem: 765.3880228703556
# Previsão para o próximo mês em Montes Claros: 1454.114390586561
# Previsão para o próximo mês em Uberlândia: 498.38251616729076
# Previsão para o próximo mês em Uberaba: 427.8513746746189
# Previsão para o próximo mês em Juiz de Fora: 567.3174696967867
# Previsão para o próximo mês em Divinópolis: 619.3717530312433
# Previsão para o próximo mês em Pouso Alegre: 332.6996245679511
# Previsão para o próximo mês em Betim: 494.530497254073
# Previsão para o próximo mês em Itajubá: 412.2276124811124

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline
import numpy as np

# 1. Leitura dos arquivos
file_path = "dados_reduzidos.csv"
populacao_path = "municipios_populacao.csv"

try:
    data = pd.read_csv(file_path, sep=';', encoding='utf-8', on_bad_lines='skip', low_memory=False)
    print(f"{file_path}: carregado com sucesso!")
except Exception as e:
    print(f"Erro ao carregar {file_path}: {e}")
    data = pd.DataFrame()

try:
    populacao = pd.read_csv(populacao_path, sep=',', encoding='utf-8')  # Correção do separador
    print(f"{populacao_path}: carregado com sucesso!")
    print("Colunas disponíveis no arquivo de população:", populacao.columns.tolist())
    
    # Garantir que os nomes das colunas estão corretos
    populacao.columns = populacao.columns.str.strip().str.lower()
    populacao.rename(columns={'municipio': 'municipio', 'populacao': 'populacao'}, inplace=True)  # Padronizar nomes
    if 'municipio' not in populacao.columns:
        raise KeyError("A coluna 'municipio' não foi encontrada no arquivo de população. Verifique o nome correto.")
except Exception as e:
    print(f"Erro ao carregar {populacao_path}: {e}")
    populacao = pd.DataFrame()

# 2. Processamento dos dados
data['dataNotificacao'] = pd.to_datetime(data['dataNotificacao'], errors='coerce')
data = data.dropna(subset=['dataNotificacao'])
data = data[data['dataNotificacao'].dt.year > 2021]
data['ano_mes'] = data['dataNotificacao'].dt.to_period('M').astype(str)

# 3. Balanceamento por população
# Normalizar nome do município e mesclar dados de população
data['municipioNotificacao'] = data['municipioNotificacao'].str.strip()
populacao['municipio'] = populacao['municipio'].str.strip()
data = data.merge(populacao, left_on='municipioNotificacao', right_on='municipio', how='left')
data.drop(columns=['municipio'], inplace=True)

# Calcular taxa de notificações por 10 mil habitantes
data['taxa_10k'] = (data.groupby(['municipioNotificacao', 'ano_mes']).transform('count')['dataNotificacao'] / data['populacao']) * 10000

data_balanceada = data.groupby(['municipioNotificacao', 'ano_mes'])['taxa_10k'].sum().reset_index()

# 4. Predição geral para MG
notificacoes_geral = data_balanceada.groupby('ano_mes')['taxa_10k'].sum().reset_index()

plt.figure(figsize=(12, 6))
plt.plot(notificacoes_geral['ano_mes'], notificacoes_geral['taxa_10k'], marker='o', linestyle='-')
plt.xticks(rotation=45)
plt.xlabel("Ano-Mês")
plt.ylabel("Notificações por 10k habitantes")
plt.title("Evolução das Notificações Balanceadas por Mês - MG")
plt.grid()
plt.show()

# 5. Predição para as 10 cidades com mais notificações balanceadas
top10_cidades = data_balanceada.groupby('municipioNotificacao')['taxa_10k'].sum().nlargest(10).index
data_top10 = data_balanceada[data_balanceada['municipioNotificacao'].isin(top10_cidades)].copy()

fig, ax = plt.subplots(figsize=(12, 6))
for municipio in top10_cidades:
    df_mun = data_top10[data_top10['municipioNotificacao'] == municipio]
    plt.plot(df_mun['ano_mes'], df_mun['taxa_10k'], marker='o', linestyle='-', label=municipio)

plt.xticks(rotation=45)
plt.xlabel("Ano-Mês")
plt.ylabel("Notificações por 10k habitantes")
plt.title("Evolução das Notificações Balanceadas - Top 10 Municípios")
plt.legend()
plt.grid()
plt.show()

# 6. Predição do próximo mês (Geral e Top 10 municípios)
def prever_proximo_mes(notificacoes):
    notificacoes = notificacoes.copy()
    notificacoes['ano_mes'] = pd.to_datetime(notificacoes['ano_mes'].astype(str))
    notificacoes['timestamp'] = (notificacoes['ano_mes'] - notificacoes['ano_mes'].min()).dt.days
    
    X = notificacoes[['timestamp']]
    y = notificacoes['taxa_10k']
    
    modelo = make_pipeline(PolynomialFeatures(2), LinearRegression())
    modelo.fit(X, y)
    
    proximo_mes = pd.DataFrame({'timestamp': [notificacoes['timestamp'].max() + 30]})
    previsao = modelo.predict(proximo_mes)
    previsao = max(0, previsao[0])
    
    return previsao

previsao_geral = prever_proximo_mes(notificacoes_geral)
print(f"Previsão para o próximo mês em MG (ajustada por 10k habitantes): {previsao_geral}")

for municipio in top10_cidades:
    df_mun = data_top10[data_top10['municipioNotificacao'] == municipio].copy()
    previsao_municipio = prever_proximo_mes(df_mun)
    print(f"Previsão para o próximo mês em {municipio} (ajustada por 10k habitantes): {previsao_municipio}")
# Out:
# dados_reduzidos.csv: carregado com sucesso!
# Erro ao carregar municipios_habitantes.csv: [Errno 2] No such file or directory: 'municipios_habitantes.csv'
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_17401/4107612451.py in <module>
#      40 # Normalizar nome do município e mesclar dados de população
#      41 data['municipioNotificacao'] = data['municipioNotificacao'].str.strip()
# ---> 42 populacao['municipio'] = populacao['municipio'].str.strip()
#      43 data = data.merge(populacao, left_on='municipioNotificacao', right_on='municipio', how='left')
#      44 data.drop(columns=['municipio'], inplace=True)
#
# ~/.local/lib/python3.10/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# ~/.local/lib/python3.10/site-packages/pandas/core/indexes/range.py in get_loc(self, key)
#     415                 raise KeyError(key) from err
#     416         if isinstance(key, Hashable):
# --> 417             raise KeyError(key)
#     418         self._check_indexing_error(key)
#     419         raise KeyError(key)
#
# KeyError: 'municipio'
